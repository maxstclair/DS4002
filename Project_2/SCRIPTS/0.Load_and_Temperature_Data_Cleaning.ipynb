# %% [markdown]
# <a href="https://colab.research.google.com/github/maxstclair/DS4002/blob/main/Load_and_Temperature_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data cleaning for hourly load demand and hourly temperature.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/miso_load-temp_hr_2021.csv")
df2 = pd.read_csv("/content/miso_load-temp_hr_2022.csv")
df3 = pd.read_csv("/content/miso_load-temp_hr_2023.csv")
df4 = pd.read_csv("/content/miso_load-temp_hr_2024.csv")
df5 = pd.read_csv("/content/miso_load-temp_hr_2025.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5])
df.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0                    2/10/21 6:00
# 1                    2/10/21 7:00
# 2                    2/10/21 8:00
# 3                    2/10/21 9:00
# 4                   2/10/21 10:00
#
#   Local Timestamp Eastern Standard Time (Interval Beginning)  \
# 0                                       2/10/21 0:00
# 1                                       2/10/21 1:00
# 2                                       2/10/21 2:00
# 3                                       2/10/21 3:00
# 4                                       2/10/21 4:00
#
#   Local Timestamp Eastern Standard Time (Interval Ending) Local Date  \
# 0                                       2/10/21 1:00         2/10/21
# 1                                       2/10/21 2:00         2/10/21
# 2                                       2/10/21 3:00         2/10/21
# 3                                       2/10/21 4:00         2/10/21
# 4                                       2/10/21 5:00         2/10/21
#
# ...

# %%
df = df.drop(columns = ["MISO Total Forecast Load (MW)", "Local Timestamp Eastern Standard Time (Interval Beginning)", "Local Timestamp Eastern Standard Time (Interval Ending)"])
df["Local Date"] = pd.to_datetime(df["Local Date"]).dt.date
df["UTC Timestamp (Interval Ending)"] = pd.to_datetime(df["UTC Timestamp (Interval Ending)"])
df = df.drop(df.columns[4:16], axis=1)
df.head()
# Out:
# <ipython-input-15-fced69234ed2>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Local Date"] = pd.to_datetime(df["Local Date"]).dt.date
# <ipython-input-15-fced69234ed2>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["UTC Timestamp (Interval Ending)"] = pd.to_datetime(df["UTC Timestamp (Interval Ending)"])
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# ...

# %%
df.to_csv('load_and_temp.csv', index=False)
